# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/User/Desktop/AI_Projects/Project_05/Data/Engineered_data/log_transform.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2052 entries, 0 to 2051
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Club                2052 non-null   float64
#  1   Squad size          2052 non-null   float64
#  2   Average age         2052 non-null   float64
#  3   Foreigners          2052 non-null   float64
#  4   Market value        2052 non-null   float64
#  5   Total market value  2052 non-null   float64
#  6   League              2052 non-null   float64
#  7   Season              2052 non-null   float64
#  8   Category            2052 non-null   int64
# dtypes: float64(8), int64(1)
# memory usage: 144.4 KB

# %%
df["Category"].value_counts()
# Out:
# Category
# 2    686
# 0    684
# 1    682
# Name: count, dtype: int64
